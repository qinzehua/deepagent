# %%
from utils import format_messages
from IPython.display import Image, display
from langgraph.checkpoint.memory import InMemorySaver
from deep_research_from_scratch.research_agent_full import deep_researcher_builder

checkpointer = InMemorySaver()
full_agent = deep_researcher_builder.compile(checkpointer=checkpointer)
display(Image(full_agent.get_graph(xray=True).draw_mermaid_png()))

# %%
from langchain_core.messages import HumanMessage
thread = {"configurable": {"thread_id": "1", "recursion_limit": 50}}
result = await full_agent.ainvoke({"messages": [HumanMessage(content="Compare Gemini to OpenAI Deep Research agents.")]}, config=thread)
format_messages(result['messages'])
# Out:
# ╭─────────────────────────────────────────────────── 🧑 Human ────────────────────────────────────────────────────╮
# │ Compare Gemini.                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────────── 📝 AI ─────────────────────────────────────────────────────╮
# │ You mentioned "Compare Gemini" — could you please clarify what you'd like me to compare Gemini with? For        │
# │ example:                                                                                                        │
# │                                                                                                                 │
# │ - **Gemini vs. ChatGPT (GPT-4/4o)**                                                                             │
# │ - **Gemini vs. Claude**                                                                                         │
# │ - **Gemini vs. Copilot / Bing Chat**                                                                            │
# │ - **Gemini vs. another specific AI model or tool?**                                                             │
# │                                                                                                                 │
# │ Also, what specific aspects are you most interested in comparing? For instance:                                 │
# │ - Capabilities and features                                                                                     │
# │ - Pricing                                                                                                       │
# │ - Performance benchmarks                                                                                        │
# │ - Use cases (coding, writing, reasoning, etc.)                                                                  │
# │ - Something else?                                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
